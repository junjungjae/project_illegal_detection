# %% [markdown]
# # Modeling Case 2 : Basic + Date + Column2
#
# - 총 23개 칼럼 (LABEL 제외)
#
# - 기본 파생변수 19개
#     - 최근 6개월간 해당 업체별 수입건수, 수입금액, 검사건수, 적발건수, 적발율
#         - R6M_CON_IMP_CNT
#         - R6M_CON_IMP_AMT
#         - R6M_CON_NUMB_OF_INSPECTION
#         - R6M_CON_NUMB_OF_DETECTED
#         - R6M_CON_RATIO_OF_DETECTED
#     - 최근 6개월간 해당 HS CODE별 수입건수, 수입금액, 검사건수, 적발건수
#         - R6M_CODE_IMP_CNT
#         - R6M_CODE_IMP_AMT
#         - R6M_CODE_NUMB_OF_INSPECTION
#         - R6M_CODE_NUMB_OF_DETECTED
#     - 최근 6개월간 해당 원산지별 수입건수, 수입금액, 검사건수, 적발건수, 적발율
#         - R6M_COUNTRY_IMP_CNT
#         - R6M_COUNTRY_IMP_AMT
#         - R6M_COUNTRY_NUMB_OF_INSPECTION
#         - R6M_COUNTRY_NUMB_OF_DETECTED
#         - R6M_COUNTRY_RATIO_OF_DETECTED
#     - 최근 6개월간 해당 관세사별 수입건수, 수입금액, 검사건수, 적발건수, 적발율
#         - R6M_REP_IMP_CNT
#         - R6M_REP_IMP_AMT
#         - R6M_REP_NUMB_OF_INSPECTION
#         - R6M_REP_NUMB_OF_DETECTED
#         - R6M_REP_RATIO_OF_DETECTED
#
# - 날짜 관련 파생변수 2개
#     - A_HOUR
#     - C_MONTH
#
# - Feature Importance 기반 기존 칼럼 2개
#     - CUS_TOTAL_NUMBER_OF_PACKAGES_6
#     - IMP_EXCHANGE_RATE_23
#
# - Modeling 모듈의 Algorithm 클래스를 사용하여 진행

# %%
def syspath(path) :
  if path not in sys.path :
    sys.path.append(path)
  else : pass

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
import sys

syspath('./dataset/mod')
warnings.filterwarnings('ignore')

# %%
from Preprocessing import Encoder
from Modeling import Algorithm

# %%
df = pd.read_pickle('./dataset/42_Basic_Date_Column2.pkl')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2146508 entries, 0 to 2146507
# Data columns (total 24 columns):
#  #   Column                          Dtype
# ---  ------                          -----
#  0   R6M_CON_IMP_CNT                 int64
#  1   R6M_CON_IMP_AMT                 float64
#  2   R6M_CON_NUMB_OF_INSPECTION      int64
#  3   R6M_CON_NUMB_OF_DETECTED        int64
#  4   R6M_CON_RATIO_OF_DETECTED       float64
#  5   R6M_CODE_IMP_CNT                int64
#  6   R6M_CODE_IMP_AMT                float64
#  7   R6M_CODE_NUMB_OF_INSPECTION     int64
#  8   R6M_CODE_NUMB_OF_DETECTED       int64
#  9   R6M_COUNTRY_IMP_CNT             int64
#  10  R6M_COUNTRY_IMP_AMT             float64
#  11  R6M_COUNTRY_NUMB_OF_INSPECTION  int64
#  12  R6M_COUNTRY_NUMB_OF_DETECTED    int64
#  13  R6M_COUNTRY_RATIO_OF_DETECTED   float64
#  14  R6M_REP_IMP_CNT                 int64
#  15  R6M_REP_IMP_AMT                 float64
#  16  R6M_REP_NUMB_OF_INSPECTION      int64
#  17  R6M_REP_NUMB_OF_DETECTED        int64
#  18  R6M_REP_RATIO_OF_DETECTED       float64
#  19  C_MONTH                         object
#  20  A_HOUR                          object
#  21  CUS_TOTAL_NUMBER_OF_PACKAGES_6  float64
#  22  IMP_EXCHANGE_RATE_23            float64
#  23  LABEL                           int64
# dtypes: float64(9), int64(13), object(2)
# memory usage: 393.0+ MB

# %% [markdown]
# ## LightGBM : Label Encoding

# %%
en = Encoder(df)
le_df = en.label()
al_l = Algorithm(le_df)
al_l.LGBM()
# Out:
# [1]	valid_0's binary_logloss: 0.600207	valid_0's binary_logloss: 0.600207
# Training until validation scores don't improve for 10 rounds.
# [2]	valid_0's binary_logloss: 0.524112	valid_0's binary_logloss: 0.524112
# [3]	valid_0's binary_logloss: 0.460658	valid_0's binary_logloss: 0.460658
# [4]	valid_0's binary_logloss: 0.407029	valid_0's binary_logloss: 0.407029
# [5]	valid_0's binary_logloss: 0.361279	valid_0's binary_logloss: 0.361279
# [6]	valid_0's binary_logloss: 0.321835	valid_0's binary_logloss: 0.321835
# [7]	valid_0's binary_logloss: 0.28766	valid_0's binary_logloss: 0.28766
# [8]	valid_0's binary_logloss: 0.257899	valid_0's binary_logloss: 0.257899
# [9]	valid_0's binary_logloss: 0.231749	valid_0's binary_logloss: 0.231749
# [10]	valid_0's binary_logloss: 0.208746	valid_0's binary_logloss: 0.208746
# [11]	valid_0's binary_logloss: 0.188586	valid_0's binary_logloss: 0.188586
# [12]	valid_0's binary_logloss: 0.170674	valid_0's binary_logloss: 0.170674
# [13]	valid_0's binary_logloss: 0.154823	valid_0's binary_logloss: 0.154823
# [14]	valid_0's binary_logloss: 0.140759	valid_0's binary_logloss: 0.140759
# [15]	valid_0's binary_logloss: 0.128228	valid_0's binary_logloss: 0.128228
# [16]	valid_0's binary_logloss: 0.117069	valid_0's binary_logloss: 0.117069
# [17]	valid_0's binary_logloss: 0.107129	valid_0's binary_logloss: 0.107129
# [18]	valid_0's binary_logloss: 0.0981857	valid_0's binary_logloss: 0.0981857
# [19]	valid_0's binary_logloss: 0.0902196	valid_0's binary_logloss: 0.0902196
# [20]	valid_0's binary_logloss: 0.0829932	valid_0's binary_logloss: 0.0829932
# [21]	valid_0's binary_logloss: 0.0765508	valid_0's binary_logloss: 0.0765508
# [22]	valid_0's binary_logloss: 0.0707072	valid_0's binary_logloss: 0.0707072
# [23]	valid_0's binary_logloss: 0.0655429	valid_0's binary_logloss: 0.0655429
# [24]	valid_0's binary_logloss: 0.0608922	valid_0's binary_logloss: 0.0608922
# [25]	valid_0's binary_logloss: 0.056617	valid_0's binary_logloss: 0.056617
# [26]	valid_0's binary_logloss: 0.0527684	valid_0's binary_logloss: 0.0527684
# [27]	valid_0's binary_logloss: 0.0493644	valid_0's binary_logloss: 0.0493644
# [28]	valid_0's binary_logloss: 0.0462284	valid_0's binary_logloss: 0.0462284
# [29]	valid_0's binary_logloss: 0.0434973	valid_0's binary_logloss: 0.0434973
# [30]	valid_0's binary_logloss: 0.0408293	valid_0's binary_logloss: 0.0408293
# [31]	valid_0's binary_logloss: 0.0385742	valid_0's binary_logloss: 0.0385742
# [32]	valid_0's binary_logloss: 0.0365342	valid_0's binary_logloss: 0.0365342
# [33]	valid_0's binary_logloss: 0.0346433	valid_0's binary_logloss: 0.0346433
# [34]	valid_0's binary_logloss: 0.0329178	valid_0's binary_logloss: 0.0329178
# [35]	valid_0's binary_logloss: 0.031166	valid_0's binary_logloss: 0.031166
# [36]	valid_0's binary_logloss: 0.0298406	valid_0's binary_logloss: 0.0298406
# [37]	valid_0's binary_logloss: 0.0283427	valid_0's binary_logloss: 0.0283427
# [38]	valid_0's binary_logloss: 0.0272587	valid_0's binary_logloss: 0.0272587
# [39]	valid_0's binary_logloss: 0.0262793	valid_0's binary_logloss: 0.0262793
# [40]	valid_0's binary_logloss: 0.025266	valid_0's binary_logloss: 0.025266
# [41]	valid_0's binary_logloss: 0.0239423	valid_0's binary_logloss: 0.0239423
# [42]	valid_0's binary_logloss: 0.023067	valid_0's binary_logloss: 0.023067
# [43]	valid_0's binary_logloss: 0.0223014	valid_0's binary_logloss: 0.0223014
# [44]	valid_0's binary_logloss: 0.0213852	valid_0's binary_logloss: 0.0213852
# [45]	valid_0's binary_logloss: 0.0207726	valid_0's binary_logloss: 0.0207726
# [46]	valid_0's binary_logloss: 0.0197614	valid_0's binary_logloss: 0.0197614
# [47]	valid_0's binary_logloss: 0.0188897	valid_0's binary_logloss: 0.0188897
# [48]	valid_0's binary_logloss: 0.0183763	valid_0's binary_logloss: 0.0183763
# [49]	valid_0's binary_logloss: 0.0178823	valid_0's binary_logloss: 0.0178823
# [50]	valid_0's binary_logloss: 0.0174424	valid_0's binary_logloss: 0.0174424
# [51]	valid_0's binary_logloss: 0.0168288	valid_0's binary_logloss: 0.0168288
# [52]	valid_0's binary_logloss: 0.0164841	valid_0's binary_logloss: 0.0164841
# [53]	valid_0's binary_logloss: 0.0161118	valid_0's binary_logloss: 0.0161118
# [54]	valid_0's binary_logloss: 0.0157349	valid_0's binary_logloss: 0.0157349
# [55]	valid_0's binary_logloss: 0.0150732	valid_0's binary_logloss: 0.0150732
# [56]	valid_0's binary_logloss: 0.0147774	valid_0's binary_logloss: 0.0147774
# [57]	valid_0's binary_logloss: 0.0143444	valid_0's binary_logloss: 0.0143444
# [58]	valid_0's binary_logloss: 0.0139712	valid_0's binary_logloss: 0.0139712
# [59]	valid_0's binary_logloss: 0.0139126	valid_0's binary_logloss: 0.0139126
# [60]	valid_0's binary_logloss: 0.0141587	valid_0's binary_logloss: 0.0141587
# [61]	valid_0's binary_logloss: 0.0144453	valid_0's binary_logloss: 0.0144453
# [62]	valid_0's binary_logloss: 0.0143609	valid_0's binary_logloss: 0.0143609
# [63]	valid_0's binary_logloss: 0.0143733	valid_0's binary_logloss: 0.0143733
# [64]	valid_0's binary_logloss: 0.0140204	valid_0's binary_logloss: 0.0140204
# [65]	valid_0's binary_logloss: 0.0149481	valid_0's binary_logloss: 0.0149481
# [66]	valid_0's binary_logloss: 0.0153462	valid_0's binary_logloss: 0.0153462
# [67]	valid_0's binary_logloss: 0.0151598	valid_0's binary_logloss: 0.0151598
# [68]	valid_0's binary_logloss: 0.0148901	valid_0's binary_logloss: 0.0148901
# [69]	valid_0's binary_logloss: 0.0146927	valid_0's binary_logloss: 0.0146927
# Early stopping, best iteration is:
# [59]	valid_0's binary_logloss: 0.0139126	valid_0's binary_logloss: 0.0139126
# Confusion Matrix
# [[426413     97]
#  [  1760   1032]]
# Accuracy : 0.9957
# Precision : 0.9141
# Recall : 0.3696
# f1 score : 0.5264
# time : 18.15106370999999

# %% [markdown]
# ## LightGBM : One-hot Encoding

# %%
oh_df = en.one_hot()
al_o = Algorithm(oh_df)
al_o.LGBM()
# Out:
# [1]	valid_0's binary_logloss: 0.600168	valid_0's binary_logloss: 0.600168
# Training until validation scores don't improve for 10 rounds.
# [2]	valid_0's binary_logloss: 0.524034	valid_0's binary_logloss: 0.524034
# [3]	valid_0's binary_logloss: 0.460553	valid_0's binary_logloss: 0.460553
# [4]	valid_0's binary_logloss: 0.406911	valid_0's binary_logloss: 0.406911
# [5]	valid_0's binary_logloss: 0.361141	valid_0's binary_logloss: 0.361141
# [6]	valid_0's binary_logloss: 0.321721	valid_0's binary_logloss: 0.321721
# [7]	valid_0's binary_logloss: 0.287527	valid_0's binary_logloss: 0.287527
# [8]	valid_0's binary_logloss: 0.257751	valid_0's binary_logloss: 0.257751
# [9]	valid_0's binary_logloss: 0.231653	valid_0's binary_logloss: 0.231653
# [10]	valid_0's binary_logloss: 0.208665	valid_0's binary_logloss: 0.208665
# [11]	valid_0's binary_logloss: 0.18842	valid_0's binary_logloss: 0.18842
# [12]	valid_0's binary_logloss: 0.170516	valid_0's binary_logloss: 0.170516
# [13]	valid_0's binary_logloss: 0.154682	valid_0's binary_logloss: 0.154682
# [14]	valid_0's binary_logloss: 0.140565	valid_0's binary_logloss: 0.140565
# [15]	valid_0's binary_logloss: 0.127983	valid_0's binary_logloss: 0.127983
# [16]	valid_0's binary_logloss: 0.116817	valid_0's binary_logloss: 0.116817
# [17]	valid_0's binary_logloss: 0.106875	valid_0's binary_logloss: 0.106875
# [18]	valid_0's binary_logloss: 0.0979494	valid_0's binary_logloss: 0.0979494
# [19]	valid_0's binary_logloss: 0.0899548	valid_0's binary_logloss: 0.0899548
# [20]	valid_0's binary_logloss: 0.0828483	valid_0's binary_logloss: 0.0828483
# [21]	valid_0's binary_logloss: 0.0763598	valid_0's binary_logloss: 0.0763598
# [22]	valid_0's binary_logloss: 0.070575	valid_0's binary_logloss: 0.070575
# [23]	valid_0's binary_logloss: 0.0653961	valid_0's binary_logloss: 0.0653961
# [24]	valid_0's binary_logloss: 0.0605777	valid_0's binary_logloss: 0.0605777
# [25]	valid_0's binary_logloss: 0.0563291	valid_0's binary_logloss: 0.0563291
# [26]	valid_0's binary_logloss: 0.0524842	valid_0's binary_logloss: 0.0524842
# [27]	valid_0's binary_logloss: 0.0491049	valid_0's binary_logloss: 0.0491049
# [28]	valid_0's binary_logloss: 0.0460415	valid_0's binary_logloss: 0.0460415
# [29]	valid_0's binary_logloss: 0.0432907	valid_0's binary_logloss: 0.0432907
# [30]	valid_0's binary_logloss: 0.0406381	valid_0's binary_logloss: 0.0406381
# [31]	valid_0's binary_logloss: 0.0380961	valid_0's binary_logloss: 0.0380961
# [32]	valid_0's binary_logloss: 0.0360383	valid_0's binary_logloss: 0.0360383
# [33]	valid_0's binary_logloss: 0.0341823	valid_0's binary_logloss: 0.0341823
# [34]	valid_0's binary_logloss: 0.0324311	valid_0's binary_logloss: 0.0324311
# [35]	valid_0's binary_logloss: 0.0308351	valid_0's binary_logloss: 0.0308351
# [36]	valid_0's binary_logloss: 0.0294939	valid_0's binary_logloss: 0.0294939
# [37]	valid_0's binary_logloss: 0.0282462	valid_0's binary_logloss: 0.0282462
# [38]	valid_0's binary_logloss: 0.0270276	valid_0's binary_logloss: 0.0270276
# [39]	valid_0's binary_logloss: 0.0259609	valid_0's binary_logloss: 0.0259609
# [40]	valid_0's binary_logloss: 0.0247963	valid_0's binary_logloss: 0.0247963
# [41]	valid_0's binary_logloss: 0.0238975	valid_0's binary_logloss: 0.0238975
# [42]	valid_0's binary_logloss: 0.0230918	valid_0's binary_logloss: 0.0230918
# [43]	valid_0's binary_logloss: 0.0221995	valid_0's binary_logloss: 0.0221995
# [44]	valid_0's binary_logloss: 0.021557	valid_0's binary_logloss: 0.021557
# [45]	valid_0's binary_logloss: 0.0206395	valid_0's binary_logloss: 0.0206395
# [46]	valid_0's binary_logloss: 0.0195035	valid_0's binary_logloss: 0.0195035
# [47]	valid_0's binary_logloss: 0.0189288	valid_0's binary_logloss: 0.0189288
# [48]	valid_0's binary_logloss: 0.0183403	valid_0's binary_logloss: 0.0183403
# [49]	valid_0's binary_logloss: 0.0174552	valid_0's binary_logloss: 0.0174552
# [50]	valid_0's binary_logloss: 0.0170107	valid_0's binary_logloss: 0.0170107
# [51]	valid_0's binary_logloss: 0.0165096	valid_0's binary_logloss: 0.0165096
# [52]	valid_0's binary_logloss: 0.0160562	valid_0's binary_logloss: 0.0160562
# [53]	valid_0's binary_logloss: 0.0154178	valid_0's binary_logloss: 0.0154178
# [54]	valid_0's binary_logloss: 0.0150854	valid_0's binary_logloss: 0.0150854
# [55]	valid_0's binary_logloss: 0.0148228	valid_0's binary_logloss: 0.0148228
# [56]	valid_0's binary_logloss: 0.0145114	valid_0's binary_logloss: 0.0145114
# [57]	valid_0's binary_logloss: 0.014221	valid_0's binary_logloss: 0.014221
# [58]	valid_0's binary_logloss: 0.0138514	valid_0's binary_logloss: 0.0138514
# [59]	valid_0's binary_logloss: 0.0135942	valid_0's binary_logloss: 0.0135942
# [60]	valid_0's binary_logloss: 0.0134633	valid_0's binary_logloss: 0.0134633
# [61]	valid_0's binary_logloss: 0.0131882	valid_0's binary_logloss: 0.0131882
# [62]	valid_0's binary_logloss: 0.0128526	valid_0's binary_logloss: 0.0128526
# [63]	valid_0's binary_logloss: 0.0135941	valid_0's binary_logloss: 0.0135941
# [64]	valid_0's binary_logloss: 0.0133849	valid_0's binary_logloss: 0.0133849
# [65]	valid_0's binary_logloss: 0.0131615	valid_0's binary_logloss: 0.0131615
# [66]	valid_0's binary_logloss: 0.0133126	valid_0's binary_logloss: 0.0133126
# [67]	valid_0's binary_logloss: 0.0129722	valid_0's binary_logloss: 0.0129722
# [68]	valid_0's binary_logloss: 0.0130449	valid_0's binary_logloss: 0.0130449
# [69]	valid_0's binary_logloss: 0.0128456	valid_0's binary_logloss: 0.0128456
# [70]	valid_0's binary_logloss: 0.0134445	valid_0's binary_logloss: 0.0134445
# [71]	valid_0's binary_logloss: 0.0130106	valid_0's binary_logloss: 0.0130106
# [72]	valid_0's binary_logloss: 0.0133211	valid_0's binary_logloss: 0.0133211
# [73]	valid_0's binary_logloss: 0.0126637	valid_0's binary_logloss: 0.0126637
# [74]	valid_0's binary_logloss: 0.0124137	valid_0's binary_logloss: 0.0124137
# [75]	valid_0's binary_logloss: 0.0125059	valid_0's binary_logloss: 0.0125059
# [76]	valid_0's binary_logloss: 0.0126721	valid_0's binary_logloss: 0.0126721
# [77]	valid_0's binary_logloss: 0.0135059	valid_0's binary_logloss: 0.0135059
# [78]	valid_0's binary_logloss: 0.0126011	valid_0's binary_logloss: 0.0126011
# [79]	valid_0's binary_logloss: 0.0136391	valid_0's binary_logloss: 0.0136391
# [80]	valid_0's binary_logloss: 0.0132265	valid_0's binary_logloss: 0.0132265
# [81]	valid_0's binary_logloss: 0.0126464	valid_0's binary_logloss: 0.0126464
# [82]	valid_0's binary_logloss: 0.0135285	valid_0's binary_logloss: 0.0135285
# [83]	valid_0's binary_logloss: 0.0143136	valid_0's binary_logloss: 0.0143136
# [84]	valid_0's binary_logloss: 0.0139742	valid_0's binary_logloss: 0.0139742
# Early stopping, best iteration is:
# [74]	valid_0's binary_logloss: 0.0124137	valid_0's binary_logloss: 0.0124137
# Confusion Matrix
# [[426360    150]
#  [  1269   1523]]
# Accuracy : 0.9967
# Precision : 0.9103
# Recall : 0.5455
# f1 score : 0.6822
# time : 22.904757827999987

# %% [markdown]
# ## CatBoost

# %%
al_o.catboost()
# Out:
# Learning rate set to 0.5
# 0:	learn: 0.0919597	total: 508ms	remaining: 50.3s
# 1:	learn: 0.0422428	total: 958ms	remaining: 46.9s
# 2:	learn: 0.0344592	total: 1.39s	remaining: 44.9s
# 3:	learn: 0.0327046	total: 1.77s	remaining: 42.5s
# 4:	learn: 0.0312388	total: 2.21s	remaining: 42.1s
# 5:	learn: 0.0296393	total: 2.68s	remaining: 42s
# 6:	learn: 0.0288357	total: 3.1s	remaining: 41.1s
# 7:	learn: 0.0279956	total: 3.55s	remaining: 40.8s
# 8:	learn: 0.0271347	total: 3.97s	remaining: 40.1s
# 9:	learn: 0.0261415	total: 4.4s	remaining: 39.6s
# 10:	learn: 0.0254946	total: 4.83s	remaining: 39.1s
# 11:	learn: 0.0250076	total: 5.28s	remaining: 38.7s
# 12:	learn: 0.0246485	total: 5.71s	remaining: 38.2s
# 13:	learn: 0.0242612	total: 6.16s	remaining: 37.8s
# 14:	learn: 0.0237225	total: 6.59s	remaining: 37.4s
# 15:	learn: 0.0231968	total: 7.06s	remaining: 37.1s
# 16:	learn: 0.0225326	total: 7.51s	remaining: 36.7s
# 17:	learn: 0.0222057	total: 7.97s	remaining: 36.3s
# 18:	learn: 0.0217076	total: 8.41s	remaining: 35.8s
# 19:	learn: 0.0211785	total: 8.85s	remaining: 35.4s
# 20:	learn: 0.0209046	total: 9.32s	remaining: 35s
# 21:	learn: 0.0204528	total: 9.78s	remaining: 34.7s
# 22:	learn: 0.0201034	total: 10.2s	remaining: 34.2s
# 23:	learn: 0.0198075	total: 10.7s	remaining: 33.8s
# 24:	learn: 0.0194212	total: 11.1s	remaining: 33.4s
# 25:	learn: 0.0188836	total: 11.6s	remaining: 33s
# 26:	learn: 0.0186003	total: 12.1s	remaining: 32.6s
# 27:	learn: 0.0183523	total: 12.5s	remaining: 32.1s
# 28:	learn: 0.0179511	total: 12.9s	remaining: 31.7s
# 29:	learn: 0.0173511	total: 13.4s	remaining: 31.2s
# 30:	learn: 0.0170444	total: 13.9s	remaining: 30.8s
# 31:	learn: 0.0167144	total: 14.3s	remaining: 30.4s
# 32:	learn: 0.0164445	total: 14.7s	remaining: 29.9s
# 33:	learn: 0.0162248	total: 15.2s	remaining: 29.5s
# 34:	learn: 0.0157742	total: 15.7s	remaining: 29.2s
# 35:	learn: 0.0154207	total: 16.2s	remaining: 28.7s
# 36:	learn: 0.0151251	total: 16.6s	remaining: 28.3s
# 37:	learn: 0.0148740	total: 17.1s	remaining: 27.9s
# 38:	learn: 0.0144392	total: 17.5s	remaining: 27.4s
# 39:	learn: 0.0142540	total: 18s	remaining: 27s
# 40:	learn: 0.0140964	total: 18.4s	remaining: 26.5s
# 41:	learn: 0.0139295	total: 18.9s	remaining: 26.1s
# 42:	learn: 0.0137430	total: 19.3s	remaining: 25.6s
# 43:	learn: 0.0135515	total: 19.8s	remaining: 25.2s
# 44:	learn: 0.0133096	total: 20.3s	remaining: 24.8s
# 45:	learn: 0.0131206	total: 20.7s	remaining: 24.3s
# 46:	learn: 0.0128769	total: 21.2s	remaining: 23.9s
# 47:	learn: 0.0126371	total: 21.6s	remaining: 23.4s
# 48:	learn: 0.0124447	total: 22.1s	remaining: 23s
# 49:	learn: 0.0122260	total: 22.5s	remaining: 22.5s
# 50:	learn: 0.0119404	total: 23s	remaining: 22.1s
# 51:	learn: 0.0116891	total: 23.5s	remaining: 21.7s
# 52:	learn: 0.0114610	total: 23.9s	remaining: 21.2s
# 53:	learn: 0.0113836	total: 24.4s	remaining: 20.8s
# 54:	learn: 0.0112810	total: 24.8s	remaining: 20.3s
# 55:	learn: 0.0111520	total: 25.3s	remaining: 19.9s
# 56:	learn: 0.0109259	total: 25.7s	remaining: 19.4s
# 57:	learn: 0.0106218	total: 26.2s	remaining: 19s
# 58:	learn: 0.0104642	total: 26.6s	remaining: 18.5s
# 59:	learn: 0.0103557	total: 27.1s	remaining: 18.1s
# 60:	learn: 0.0102570	total: 27.6s	remaining: 17.6s
# 61:	learn: 0.0100350	total: 28s	remaining: 17.2s
# 62:	learn: 0.0099068	total: 28.5s	remaining: 16.7s
# 63:	learn: 0.0098294	total: 28.9s	remaining: 16.3s
# 64:	learn: 0.0097180	total: 29.4s	remaining: 15.8s
# 65:	learn: 0.0096532	total: 29.9s	remaining: 15.4s
# 66:	learn: 0.0095505	total: 30.3s	remaining: 14.9s
# 67:	learn: 0.0094041	total: 30.8s	remaining: 14.5s
# 68:	learn: 0.0092879	total: 31.2s	remaining: 14s
# 69:	learn: 0.0091920	total: 31.6s	remaining: 13.6s
# 70:	learn: 0.0090749	total: 32.1s	remaining: 13.1s
# 71:	learn: 0.0089051	total: 32.6s	remaining: 12.7s
# 72:	learn: 0.0087589	total: 33.1s	remaining: 12.2s
# 73:	learn: 0.0086795	total: 33.5s	remaining: 11.8s
# 74:	learn: 0.0086612	total: 34s	remaining: 11.3s
# 75:	learn: 0.0085212	total: 34.4s	remaining: 10.9s
# 76:	learn: 0.0084463	total: 34.9s	remaining: 10.4s
# 77:	learn: 0.0083117	total: 35.3s	remaining: 9.96s
# 78:	learn: 0.0082522	total: 35.8s	remaining: 9.51s
# 79:	learn: 0.0081433	total: 36.2s	remaining: 9.06s
# 80:	learn: 0.0080252	total: 36.7s	remaining: 8.61s
# 81:	learn: 0.0079932	total: 37.2s	remaining: 8.16s
# 82:	learn: 0.0078882	total: 37.6s	remaining: 7.7s
# 83:	learn: 0.0078265	total: 38.1s	remaining: 7.25s
# 84:	learn: 0.0076914	total: 38.5s	remaining: 6.8s
# 85:	learn: 0.0075672	total: 39s	remaining: 6.35s
# 86:	learn: 0.0074938	total: 39.4s	remaining: 5.89s
# 87:	learn: 0.0074641	total: 39.9s	remaining: 5.44s
# 88:	learn: 0.0073655	total: 40.3s	remaining: 4.99s
# 89:	learn: 0.0072812	total: 40.8s	remaining: 4.53s
# 90:	learn: 0.0072575	total: 41.2s	remaining: 4.08s
# 91:	learn: 0.0071008	total: 41.7s	remaining: 3.63s
# 92:	learn: 0.0069940	total: 42.2s	remaining: 3.17s
# 93:	learn: 0.0069196	total: 42.6s	remaining: 2.72s
# 94:	learn: 0.0068255	total: 43.1s	remaining: 2.27s
# 95:	learn: 0.0067940	total: 43.5s	remaining: 1.81s
# 96:	learn: 0.0066682	total: 44s	remaining: 1.36s
# 97:	learn: 0.0066342	total: 44.5s	remaining: 908ms
# 98:	learn: 0.0065516	total: 45s	remaining: 454ms
# 99:	learn: 0.0064084	total: 45.4s	remaining: 0us
# Confusion Matrix
# [[426453     57]
#  [   574   2218]]
# Accuracy : 0.9985
# Precision : 0.9749
# Recall : 0.7944
# f1 score : 0.8755
# time : 48.33056381700001

# %% [markdown]
# ## MLP

# %%
al_o.MLP()
# Out:
# Confusion Matrix
# [[426209    301]
#  [  1437   1355]]
# Accuracy : 0.9960
# Precision : 0.8182
# Recall : 0.4853
# f1 score : 0.6093
# time : 496.47038261999995

# %% [markdown]
# ## Random Forest

# %%
al_o.RF()
# Out:
# Confusion Matrix
# [[426503      7]
#  [    24   2768]]
# Accuracy : 0.9999
# Precision : 0.9975
# Recall : 0.9914
# f1 score : 0.9944
# time : 340.34603880500015
